# %%
#Loading the libraries
import pandas as pd
import numpy as np

# %%
# Loading the dataset
df= pd.read_csv('Weed_Price.csv')

# %%
print(df.head(3))

print("\n",df.shape)
# Out:
#      State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date
# 0  Alabama  339.06    1042  198.64    933  149.49    123  2014-01-01
# 1   Alaska  288.75     252  260.60    297  388.58     26  2014-01-01
# 2  Arizona  303.31    1941  209.35   1625  189.45    222  2014-01-01
#
#  (22899, 8)

# %%
#information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22899 entries, 0 to 22898
# Data columns (total 8 columns):
# State     22899 non-null object
# HighQ     22899 non-null float64
# HighQN    22899 non-null int64
# MedQ      22899 non-null float64
# MedQN     22899 non-null int64
# LowQ      12342 non-null float64
# LowQN     22899 non-null int64
# date      22899 non-null object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#               HighQ        HighQN          MedQ         MedQN          LowQ  \
# count  22899.000000  22899.000000  22899.000000  22899.000000  12342.000000
# mean     329.759854   2274.743657    247.618306   2183.737805    203.747847
# std       41.173167   2641.936586     44.276015   2789.902626    105.480774
# min      202.020000     93.000000    144.850000    134.000000     63.700000
# 25%      303.780000    597.000000    215.775000    548.000000    147.117500
# 50%      342.310000   1420.000000    245.800000   1320.000000    186.760000
# 75%      356.550000   2958.000000    274.155000   2673.000000    221.360000
# max      415.700000  18492.000000    379.000000  22027.000000    734.650000
#
#               LowQN
# count  22899.000000
# mean     202.804489
# std      220.531987
# min       11.000000
# 25%       51.000000
# 50%      139.000000
# 75%      263.000000
# max     1287.000000

# %%
#changing the data type of date from object to date type
df['date']=pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22899 entries, 0 to 22898
# Data columns (total 8 columns):
# State     22899 non-null object
# HighQ     22899 non-null float64
# HighQN    22899 non-null int64
# MedQ      22899 non-null float64
# MedQN     22899 non-null int64
# LowQ      12342 non-null float64
# LowQN     22899 non-null int64
# date      22899 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(3), object(1)
# memory usage: 1.4+ MB

# %%
#bottom five rows
df.tail(5)
# Out:
#                State   HighQ  HighQN    MedQ  MedQN  LowQ  LowQN       date
# 22894       Virginia  364.98    3513  293.12   3079   NaN    284 2014-12-31
# 22895     Washington  233.05    3337  189.92   3562   NaN    160 2014-12-31
# 22896  West Virginia  359.35     551  224.03    545   NaN     60 2014-12-31
# 22897      Wisconsin  350.52    2244  272.71   2221   NaN    167 2014-12-31
# 22898        Wyoming  322.27     131  351.86    197   NaN     12 2014-12-31

# %%
import time

# %%
#Thinking in Vectors

#Difference between loops and vectors

# %%
#It is easy to convert pandas series to numpy array.
highq_np = np.array(df.HighQ)
medq_np = np.array(df.MedQ)

# %%
#Standard pythonic code
start_time =time.time()
def find_weighted_price():
    global weighted_price
    weighted_price = []
    
    for i in range(df.shape[0]):
        weighted_price.append(0.6*highq_np[i]*0.4*highq_np[i])

#print the weighted price
find_weighted_price()
print (weighted_price)
print('\n',(time.time()-start_time))
# Out:
# [27590.804064000004, 20010.375, 22079.269463999997, 31424.501400000005, 14853.957216, 13402.179864000002, 29048.258399999995, 33423.194976, 29780.905823999998, 22535.842776, 26487.236183999998, 23207.069183999996, 18288.8646, 31059.088224000003, 27224.217600000004, 33158.6136, 29992.636823999997, 27309.966936, 34239.56258399999, 24745.250400000004, 18779.729496, 29845.192704, 17445.492504, 32232.062616000007, 30230.665944000008, 20724.887904000003, 29733.580896000007, 30396.137856, 40904.847744, 27196.741656000002, 31898.708376000002, 10938.715224000001, 34661.472215999995, 30218.742143999996, 21507.938304000003, 33065.902176, 27789.714815999996, 33135.423576, 33333.691776, 26980.652184000006, 29302.640736000005, 36093.3216, 31060.815000000002, 28290.117336000003, 20398.937184000002, 34634.115456, 33572.035224, 13370.438616, 31242.3936, 30757.641624000004, 30399.554399999997, 27343.980384000002, 22037.068896, 21385.972823999997, 28018.853376000003, 14283.955584000001, 14255.865216, 2
# ...

# %%
#Vectorized Code
start_time=time.time()
weighted_price_vec = 0.6*highq_np + 0.4*medq_np
print('\n',(time.time()-start_time))
# Out:
#  0.0004031658172607422
